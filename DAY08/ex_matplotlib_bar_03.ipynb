# %% [markdown]
# ### 막대그래프 활용

# %%
# [1] 모듈 로딩
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# [2] 데이터 준비
species = ('Adelie', 'Chinstrap', 'Gentoo') # x축애 들어갈 품종
sex_counts = {
    'Male': np.array([73, 34, 61]),
    'Female': np.array([73, 34, 58]),  # y축에 들어갈 값
}
width = 0.6  # the width of the bars: can also be len(x) sequence

# %%
# [3] 펭귄 품종 시각화
# - 품종에 따른 성별 비교
fig, ax = plt.subplots()
bottom = np.zeros(3)

for sex, sex_count in sex_counts.items():
    # bottom 매개변수 : 누적
    p = ax.bar(species, sex_count, width, label=sex, bottom=bottom)
    bottom += sex_count # male 먼저 들어오고 그 값이 바닥 값으로 됨. 그 다음 female의 값이 그 위에 쌓임. 결국 누적 그래프 그리는 것

    # 막대 그래프 내에 라벨 추가
    ax.bar_label(p, label_type='center') # 막대 그래프 안에 값을 넣어달라.

# ax.set_title('Number of penguins by sex')
ax.set(title='Number of penguins by sex',xlabel='Penguins',ylabel='count')
ax.legend()

plt.show()

# %% [markdown]
# * [다중막대그래프]

# %%
# x축 데이터
species = ("Adelie", "Chinstrap", "Gentoo")

# y축 데이터
penguin_means = {
    'Bill Depth': (18.35, 18.43, 14.98),
    'Bill Length': (38.79, 48.83, 47.50),
    'Flipper Length': (189.95, 195.82, 217.19),
}

# 그래프에 나타낼 x축 위치 값, 막대 그래프 너비, 다중 막대 그래프 간격 값
x = np.arange(len(species))  # (0,3,1)
width = 0.25                 # the width of the bars
multiplier = 0               # 막대그래프 간격

# %%
# 품종별 특징 비교 다중 그래프
fig, ax = plt.subplots(layout='constrained')

# 막대 그리기 부분
for attribute, measurement in penguin_means.items():
    offset = width * multiplier
    rects = ax.bar(x + offset, measurement, width, label=attribute)
    #              막대 시작점
    ax.bar_label(rects, padding=3)
    multiplier += 1

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Length (mm)')
ax.set_title('Penguin attributes by species')
ax.set_xticks(x + width, species)
ax.legend(loc='upper left', ncols=3) # ncols => 난 옆으로 쓰고 싶다!
ax.set_ylim(0, 250)

plt.show()
