# %% [markdown]
# #### Ensemble - RandomForest & ExtraTree
# - 배깅 방식의 앙상블 ==> 중복 랜덤 샘플 + 동일 모델(DT)
#     * 대표 알고리즘 : RandomForestC/R
# - 페이스트 방식의 앙상블 ==> 랜덤 샘플 + 동일 모델(DT)
#     * 대표 알고리즘 : ExtraTreeC/R

# %% [markdown]
# [목표] 와인분류 => 0과 1 2개 종류 분류

# %% [markdown]
# [1] 모듈 로딩 및 데이터 준비

# %%
# 모듈로딩
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# 데이터
DATA_FILE = r'C:\VSCode\KDT\머신러닝\DAY08\wine.csv'

# CSV => DF
wineDF = pd.read_csv(DATA_FILE)

# %%
# 데이터 확인
wineDF.head()
# Out:
#    alcohol  sugar    pH  class
# 0      9.4    1.9  3.51    0.0
# 1      9.8    2.6  3.20    0.0
# 2      9.8    2.3  3.26    0.0
# 3      9.8    1.9  3.16    0.0
# 4      9.4    1.9  3.51    0.0

# %%
wineDF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6497 entries, 0 to 6496
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   alcohol  6497 non-null   float64
#  1   sugar    6497 non-null   float64
#  2   pH       6497 non-null   float64
#  3   class    6497 non-null   float64
# dtypes: float64(4)
# memory usage: 203.2 KB

# %%
# 타겟/라벨의 클래스 분포
wineDF['class'].value_counts()
# Out:
# class
# 1.0    4898
# 0.0    1599
# Name: count, dtype: int64

# %%
wineDF.describe()
# 각 feature간 범위가 차이가 나기 때문에 스케일링도 고려해야됨. but DT에서는 필요없음.
# Out:
#            alcohol        sugar           pH        class
# count  6497.000000  6497.000000  6497.000000  6497.000000
# mean     10.491801     5.443235     3.218501     0.753886
# std       1.192712     4.757804     0.160787     0.430779
# min       8.000000     0.600000     2.720000     0.000000
# 25%       9.500000     1.800000     3.110000     1.000000
# 50%      10.300000     3.000000     3.210000     1.000000
# 75%      11.300000     8.100000     3.320000     1.000000
# max      14.900000    65.800000     4.010000     1.000000

# %% [markdown]
# [2] 학습 준비

# %%
# 학습용 & 테스트용 데이터셋 분할
from sklearn.model_selection import train_test_split

# %%
featureDF = wineDF[wineDF.columns[:-1]]
targetSR = wineDF[wineDF.columns[-1]]

print(f'featureDF : {featureDF.shape} targetSR : {targetSR.shape}')
# Out:
# featureDF : (6497, 3) targetSR : (6497,)

# %%
# 학습용, 테스트용 데이터셋 분리
X_train,X_test,y_train,y_test = train_test_split(featureDF,
                                                 targetSR,
                                                 random_state=1,
                                                 test_size = 0.2,
                                                 stratify = targetSR)

# %%
print(f'X_train : {X_train.shape} y_train : {y_train.shape}')
print(f'X_test : {X_test.shape} y_test : {y_test.shape}')
# Out:
# X_train : (5197, 3) y_train : (5197,)
# X_test : (1300, 3) y_test : (1300,)

# %% [markdown]
# [3] 학습 진행

# %%
# 학습방법 : 지도학습 > 분류
# 알고리즘 : 앙상블 > 배깅 - RandomForestClassifier

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
# 인스턴스 생성 => 100개의 내부 DT 모델에서 사용할 데이터셋 생성
#                 random_state 매개변수 설정으로 고정된 데이터셋 생성
#                 oob_score 매개변수 : 샘플 데이터셋 추출 후 남은 데이터셋 검증용으로 사용
lf_model = RandomForestClassifier(random_state=7,oob_score=True)

# 학습
lf_model.fit(X_train,y_train)
# Out:
# RandomForestClassifier(oob_score=True, random_state=7)

# %%
# 모델 파라미터
print(f'classes_ : {lf_model.classes_}')
print(f'n_classes_ : {lf_model.n_classes_}개')
print()
print(f'feature_names_in_ : {lf_model.feature_names_in_}')
print(f'n_features_in_ : {lf_model.n_features_in_}개')
print(f'feature_importances_: {lf_model.feature_importances_}')
# Out:
# classes_ : [0. 1.]
# n_classes_ : 2개
#
# feature_names_in_ : ['alcohol' 'sugar' 'pH']
# n_features_in_ : 3개
# feature_importances_: [0.23572103 0.49995154 0.26432743]

# %%
# 모델 파라미터
for est in lf_model.estimators_:
    print(est)
# Out:
# DecisionTreeClassifier(max_features='sqrt', random_state=327741615)
# DecisionTreeClassifier(max_features='sqrt', random_state=976413892)
# DecisionTreeClassifier(max_features='sqrt', random_state=1202242073)
# DecisionTreeClassifier(max_features='sqrt', random_state=1369975286)
# DecisionTreeClassifier(max_features='sqrt', random_state=1882953283)
# DecisionTreeClassifier(max_features='sqrt', random_state=2053951699)
# DecisionTreeClassifier(max_features='sqrt', random_state=959775639)
# DecisionTreeClassifier(max_features='sqrt', random_state=1956722279)
# DecisionTreeClassifier(max_features='sqrt', random_state=2052949340)
# DecisionTreeClassifier(max_features='sqrt', random_state=1322904761)
# DecisionTreeClassifier(max_features='sqrt', random_state=165338510)
# DecisionTreeClassifier(max_features='sqrt', random_state=1133316631)
# DecisionTreeClassifier(max_features='sqrt', random_state=4812360)
# DecisionTreeClassifier(max_features='sqrt', random_state=372560217)
# DecisionTreeClassifier(max_features='sqrt', random_state=309457262)
# DecisionTreeClassifier(max_features='sqrt', random_state=1801189930)
# DecisionTreeClassifier(max_features='sqrt', random_state=1152936666)
# DecisionTreeClassifier(max_features='sqrt', random_state=68334472)
# DecisionTreeClassifier(max_features='sqrt', random_state=2146978983)
# DecisionTreeClassifier(max_features='sqrt', random_state=119248870)
# DecisionTreeClassifier(max_features='sqrt', random_state=769786948)
# DecisionTreeClassifier(max_features='sqrt', random_state=1583990192)
# DecisionTreeClassifier(max_features='sqrt', random_state=1304549247)
# DecisionTreeClassifier(max_features='sqrt', random_state=1420943751)
# DecisionTreeClassifier(max_features='sqrt', random_state=1636129708)
# DecisionTreeClassifier(max_features='sqrt', random_state=1687674368)
# DecisionTreeClassifier(max_features='sqrt', random_state=283194443)
# DecisionTreeClassifier(max_features='sqrt', random_state=748743479)
# DecisionTreeClassifier(max_features='sqrt', random_state=1237575930)
# DecisionTreeClassifier(max_features='sqrt', random_state=740097030)
# DecisionTreeClassifier(max_features='sqrt', random_state=1759190803)
# DecisionTreeClassifier(max_features='sqrt', random_state=833359292)
# DecisionTreeClassifier(max_features='sqrt', random_state=916483116)
# DecisionTreeClassifier(max_features='sqrt', random_state=1485942463)
# DecisionTreeClassifier(max_features='sqrt', random_state=1941857605)
# DecisionTreeClassifier(max_features='sqrt', random_state=1844809528)
# DecisionTreeClassifier(max_features='sqrt', random_state=1852015768)
# DecisionTreeClassifier(max_features='sqrt', random_state=1127788727)
# DecisionTreeClassifier(max_features='sqrt', random_state=106941365)
# DecisionTreeClassifier(max_features='sqrt', random_state=1077017712)
# DecisionTreeClassifier(max_features='sqrt', random_state=431854331)
# DecisionTreeClassifier(max_features='sqrt', random_state=1094761661)
# DecisionTreeClassifier(max_features='sqrt', random_state=1933291456)
# DecisionTreeClassifier(max_features='sqrt', random_state=1508798754)
# DecisionTreeClassifier(max_features='sqrt', random_state=989143352)
# DecisionTreeClassifier(max_features='sqrt', random_state=747550921)
# DecisionTreeClassifier(max_features='sqrt', random_state=208262606)
# DecisionTreeClassifier(max_features='sqrt', random_state=1248819750)
# DecisionTreeClassifier(max_features='sqrt', random_state=1757192964)
# DecisionTreeClassifier(max_features='sqrt', random_state=1879603694)
# DecisionTreeClassifier(max_features='sqrt', random_state=571958409)
# DecisionTreeClassifier(max_features='sqrt', random_state=1927692119)
# DecisionTreeClassifier(max_features='sqrt', random_state=100556259)
# DecisionTreeClassifier(max_features='sqrt', random_state=1652057283)
# DecisionTreeClassifier(max_features='sqrt', random_state=1075502152)
# DecisionTreeClassifier(max_features='sqrt', random_state=1535344467)
# DecisionTreeClassifier(max_features='sqrt', random_state=725906352)
# DecisionTreeClassifier(max_features='sqrt', random_state=830456065)
# DecisionTreeClassifier(max_features='sqrt', random_state=2008983232)
# DecisionTreeClassifier(max_features='sqrt', random_state=431532432)
# DecisionTreeClassifier(max_features='sqrt', random_state=879820150)
# DecisionTreeClassifier(max_features='sqrt', random_state=2072909727)
# DecisionTreeClassifier(max_features='sqrt', random_state=2107823453)
# DecisionTreeClassifier(max_features='sqrt', random_state=488352684)
# DecisionTreeClassifier(max_features='sqrt', random_state=1599380060)
# DecisionTreeClassifier(max_features='sqrt', random_state=1938096892)
# DecisionTreeClassifier(max_features='sqrt', random_state=2050422343)
# DecisionTreeClassifier(max_features='sqrt', random_state=1497897239)
# DecisionTreeClassifier(max_features='sqrt', random_state=1571487242)
# DecisionTreeClassifier(max_features='sqrt', random_state=1187621609)
# DecisionTreeClassifier(max_features='sqrt', random_state=1451346723)
# DecisionTreeClassifier(max_features='sqrt', random_state=1917728192)
# DecisionTreeClassifier(max_features='sqrt', random_state=1153832253)
# DecisionTreeClassifier(max_features='sqrt', random_state=1966724487)
# DecisionTreeClassifier(max_features='sqrt', random_state=1348596887)
# DecisionTreeClassifier(max_features='sqrt', random_state=771276892)
# DecisionTreeClassifier(max_features='sqrt', random_state=311923447)
# DecisionTreeClassifier(max_features='sqrt', random_state=612959456)
# DecisionTreeClassifier(max_features='sqrt', random_state=1185621653)
# DecisionTreeClassifier(max_features='sqrt', random_state=358664548)
# DecisionTreeClassifier(max_features='sqrt', random_state=1944945571)
# DecisionTreeClassifier(max_features='sqrt', random_state=202873313)
# DecisionTreeClassifier(max_features='sqrt', random_state=1516030531)
# DecisionTreeClassifier(max_features='sqrt', random_state=1332338555)
# DecisionTreeClassifier(max_features='sqrt', random_state=676025563)
# DecisionTreeClassifier(max_features='sqrt', random_state=1214271969)
# DecisionTreeClassifier(max_features='sqrt', random_state=1590645779)
# DecisionTreeClassifier(max_features='sqrt', random_state=1808153499)
# DecisionTreeClassifier(max_features='sqrt', random_state=1971789316)
# DecisionTreeClassifier(max_features='sqrt', random_state=1861190419)
# DecisionTreeClassifier(max_features='sqrt', random_state=941989921)
# DecisionTreeClassifier(max_features='sqrt', random_state=1798548603)
# DecisionTreeClassifier(max_features='sqrt', random_state=1773786398)
# DecisionTreeClassifier(max_features='sqrt', random_state=2088312505)
# DecisionTreeClassifier(max_features='sqrt', random_state=1745574629)
# DecisionTreeClassifier(max_features='sqrt', random_state=1260873545)
# DecisionTreeClassifier(max_features='sqrt', random_state=775033821)
# DecisionTreeClassifier(max_features='sqrt', random_state=1474484177)
# DecisionTreeClassifier(max_features='sqrt', random_state=1035597695)
# DecisionTreeClassifier(max_features='sqrt', random_state=1289946527)

# %%
print(f'oob_score_ : {lf_model.oob_score_}')
# Out:
# oob_score_ : 0.89532422551472

# %% [markdown]
# [4] 성능평가

# %%
train_score = lf_model.score(X_train,y_train)
test_score = lf_model.score(X_test,y_test)

# %%
print(f'train_score : {train_score}, test_score : {test_score}')
# Out:
# train_score : 0.9973061381566288, test_score : 0.9

# %% [markdown]
# [5] 튜닝

# %% [markdown]
# * RandomizedSearchCV 하이퍼파라미터 최적화 클래스
#     * 범위가 넓은 하이퍼파라미터 설정에 좋음
#     * 지정된 범위에서 지정된 횟수만큼 하이퍼파라미터를 추출하여 조합 진행

# %%
# 모듈 로딩
from sklearn.model_selection import RandomizedSearchCV

# %%
# RandomForestClassifier 하이퍼파라미터 설정
params = {'max_depth': range(2,16),
          'min_samples_leaf' : range(5,16),
          'criterion' : ['gini','entropy','log_loss']}

# %%
rf_model = RandomForestClassifier(random_state=7)

# %%
searchCV = RandomizedSearchCV(rf_model,param_distributions=params,
                              n_iter = 50,
                              verbose=4)
# n_iter의 값에 따라 모델의 개수가 정해짐.

# %%
searchCV.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# [CV 1/5] END criterion=log_loss, max_depth=11, min_samples_leaf=11;, score=0.870 total time=   0.1s
# [CV 2/5] END criterion=log_loss, max_depth=11, min_samples_leaf=11;, score=0.838 total time=   0.2s
# [CV 3/5] END criterion=log_loss, max_depth=11, min_samples_leaf=11;, score=0.877 total time=   0.1s
# [CV 4/5] END criterion=log_loss, max_depth=11, min_samples_leaf=11;, score=0.885 total time=   0.2s
# [CV 5/5] END criterion=log_loss, max_depth=11, min_samples_leaf=11;, score=0.875 total time=   0.2s
# [CV 1/5] END criterion=gini, max_depth=15, min_samples_leaf=10;, score=0.872 total time=   0.1s
# [CV 2/5] END criterion=gini, max_depth=15, min_samples_leaf=10;, score=0.836 total time=   0.2s
# [CV 3/5] END criterion=gini, max_depth=15, min_samples_leaf=10;, score=0.880 total time=   0.2s
# [CV 4/5] END criterion=gini, max_depth=15, min_samples_leaf=10;, score=0.883 total time=   0.1s
# [CV 5/5] END criterion=gini, max_depth=15, min_samples_leaf=10;, score=0.873 total time=   0.2s
# [CV 1/5] END criterion=gini, max_depth=10, min_samples_leaf=14;, score=0.875 total time=   0.1s
# [CV 2/5] END criterion=gini, max_depth=10, min_samples_leaf=14;, score=0.832 total time=   0.1s
# [CV 3/5] END criterion=gini, max_depth=10, min_samples_leaf=14;, score=0.879 total time=   0.1s
# [CV 4/5] END criterion=gini, max_depth=10, min_samples_leaf=14;, score=0.881 total time=   0.1s
# [CV 5/5] END criterion=gini, max_depth=10, min_samples_leaf=14;, score=0.869 total time=   0.1s
# [CV 1/5] END criterion=entropy, max_depth=5, min_samples_leaf=5;, score=0.851 total time=   0.1s
# [CV 2/5] END criterion=entropy, max_depth=5, min_samples_leaf=5;, score=0.842 total time=   0.1s
# [CV 3/5] END criterion=entropy, max_depth=5, min_samples_leaf=5;, score=0.859 total time=   0.1s
# [CV 4/5] END criterion=entropy, max_depth=5, min_samples_leaf=5;, score=0.875 total time=   0.1s
# [CV 5/5] END criterion=entropy, max_depth=5, min_samples_leaf=5;, score=0.865 total time=   0.1s
# [CV 1/5] END criterion=log_loss, max_depth=4, min_samples_leaf=13;, score=0.835 total time=   0.0s
# [CV 2/5] END criterion=log_loss, max_depth=4, min_samples_leaf=13;, score=0.833 total time=   0.1s
# [CV 3/5] END criterion=log_loss, max_depth=4, min_samples_leaf=13;, score=0.851 total time=   0.0s
# [CV 4/5] END criterion=log_loss, max_depth=4, min_samples_leaf=13;, score=0.859 total time=   0.1s
# [CV 5/5] END criterion=log_loss, max_depth=4, min_samples_leaf=13;, score=0.845 total time=   0.1s
# [CV 1/5] END criterion=entropy, max_depth=5, min_samples_leaf=12;, score=0.854 total time=   0.1s
# [CV 2/5] END criterion=entropy, max_depth=5, min_samples_leaf=12;, score=0.836 total time=   0.1s
# [CV 3/5] END criterion=entropy, max_depth=5, min_samples_leaf=12;, score=0.861 total time=   0.1s
# [CV 4/5] END criterion=entropy, max_depth=5, min_samples_leaf=12;, score=0.875 total time=   0.1s
# [CV 5/5] END criterion=entropy, max_depth=5, min_samples_leaf=12;, score=0.859 total time=   0.1s
# [CV 1/5] END criterion=log_loss, max_depth=14, min_samples_leaf=7;, score=0.883 total time=   0.1s
# [CV 2/5] END criterion=log_loss, max_depth=14, min_samples_leaf=7;, score=0.846 total time=   0.1s
# [CV 3/5] END criterion=log_loss, max_depth=14, min_samples_leaf=7;, score=0.881 total time=   0.1s
# [CV 4/5] END criterion=log_loss, max_depth=14, min_samples_leaf=7;, score=0.886 total time=   0.1s
# [CV 5/5] END criterion=log_loss, max_depth=14, min_samples_leaf=7;, score=0.879 total time=   0.1s
# [CV 1/5] END criterion=log_loss, max_depth=3, min_samples_leaf=13;, score=0.799 total time=   0.0s
# [CV 2/5] END criterion=log_loss, max_depth=3, min_samples_leaf=13;, score=0.801 total time=   0.0s
# [CV 3/5] END criterion=log_loss, max_depth=3, min_samples_leaf=13;, score=0.808 total time=   0.0s
# [CV 4/5] END criterion=log_loss, max_depth=3, min_samples_leaf=13;, score=0.830 total time=   0.1s
# [CV 5/5] END criterion=log_loss, max_depth=3, min_samples_leaf=13;, score=0.819 total time=   0.0s
# [CV 1/5] END criterion=log_loss, max_depth=2, min_samples_leaf=10;, score=0.754 total time=   0.0s
# [CV 2/5] END criterion=log_loss, max_depth=2, min_samples_leaf=10;, score=0.754 total time=   0.0s
# [CV 3/5] END criterion=log_loss, max_depth=2, min_samples_leaf=10;, score=0.755 total time=   0.0s
# [CV 4/5] END criterion=log_loss, max_depth=2, min_samples_leaf=10;, score=0.754 total time=   0.0s
# [CV 5/5] END criterion=log_loss, max_depth=2, min_samples_leaf=10;, score=0.754 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=2, min_samples_leaf=10;, score=0.756 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=2, min_samples_leaf=10;, score=0.767 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=2, min_samples_leaf=10;, score=0.771 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=2, min_samples_leaf=10;, score=0.754 total time=   0.1s
# [CV 5/5] END criterion=gini, max_depth=2, min_samples_leaf=10;, score=0.754 total time=   0.0s
# [CV 1/5] END criterion=entropy, max_depth=10, min_samples_leaf=13;, score=0.872 total time=   0.1s
# [CV 2/5] END criterion=entropy, max_depth=10, min_samples_leaf=13;, score=0.835 total time=   0.1s
# [CV 3/5] END criterion=entropy, max_depth=10, min_samples_leaf=13;, score=0.871 total time=   0.1s
# [CV 4/5] END criterion=entropy, max_depth=10, min_samples_leaf=13;, score=0.885 total time=   0.1s
# [CV 5/5] END criterion=entropy, max_depth=10, min_samples_leaf=13;, score=0.867 total time=   0.1s
# [CV 1/5] END criterion=gini, max_depth=14, min_samples_leaf=9;, score=0.879 total time=   0.1s
# [CV 2/5] END criterion=gini, max_depth=14, min_samples_leaf=9;, score=0.838 total time=   0.1s
# [CV 3/5] END criterion=gini, max_depth=14, min_samples_leaf=9;, score=0.880 total time=   0.1s
# [CV 4/5] END criterion=gini, max_depth=14, min_samples_leaf=9;, score=0.885 total time=   0.1s
# [CV 5/5] END criterion=gini, max_depth=14, min_samples_leaf=9;, score=0.877 total time=   0.1s
# [CV 1/5] END criterion=log_loss, max_depth=5, min_samples_leaf=10;, score=0.853 total time=   0.1s
# [CV 2/5] END criterion=log_loss, max_depth=5, min_samples_leaf=10;, score=0.838 total time=   0.1s
# [CV 3/5] END criterion=log_loss, max_depth=5, min_samples_leaf=10;, score=0.860 total time=   0.1s
# [CV 4/5] END criterion=log_loss, max_depth=5, min_samples_leaf=10;, score=0.877 total time=   0.1s
# [CV 5/5] END criterion=log_loss, max_depth=5, min_samples_leaf=10;, score=0.860 total time=   0.1s
# [CV 1/5] END criterion=gini, max_depth=14, min_samples_leaf=12;, score=0.875 total time=   0.1s
# [CV 2/5] END criterion=gini, max_depth=14, min_samples_leaf=12;, score=0.833 total time=   0.1s
# [CV 3/5] END criterion=gini, max_depth=14, min_samples_leaf=12;, score=0.880 total time=   0.1s
# [CV 4/5] END criterion=gini, max_depth=14, min_samples_leaf=12;, score=0.883 total time=   0.1s
# [CV 5/5] END criterion=gini, max_depth=14, min_samples_leaf=12;, score=0.875 total time=   0.1s
# [CV 1/5] END criterion=gini, max_depth=5, min_samples_leaf=12;, score=0.857 total time=   0.1s
# [CV 2/5] END criterion=gini, max_depth=5, min_samples_leaf=12;, score=0.828 total time=   0.1s
# [CV 3/5] END criterion=gini, max_depth=5, min_samples_leaf=12;, score=0.864 total time=   0.1s
# [CV 4/5] END criterion=gini, max_depth=5, min_samples_leaf=12;, score=0.875 total time=   0.1s
# [CV 5/5] END criterion=gini, max_depth=5, min_samples_leaf=12;, score=0.851 total time=   0.1s
# [CV 1/5] END criterion=entropy, max_depth=7, min_samples_leaf=10;, score=0.862 total time=   0.1s
# [CV 2/5] END criterion=entropy, max_depth=7, min_samples_leaf=10;, score=0.837 total time=   0.1s
# [CV 3/5] END criterion=entropy, max_depth=7, min_samples_leaf=10;, score=0.883 total time=   0.1s
# [CV 4/5] END criterion=entropy, max_depth=7, min_samples_leaf=10;, score=0.877 total time=   0.1s
# [CV 5/5] END criterion=entropy, max_depth=7, min_samples_leaf=10;, score=0.864 total time=   0.1s
# [CV 1/5] END criterion=log_loss, max_depth=12, min_samples_leaf=15;, score=0.875 total time=   0.1s
# [CV 2/5] END criterion=log_loss, max_depth=12, min_samples_leaf=15;, score=0.837 total time=   0.1s
# [CV 3/5] END criterion=log_loss, max_depth=12, min_samples_leaf=15;, score=0.874 total time=   0.1s
# [CV 4/5] END criterion=log_loss, max_depth=12, min_samples_leaf=15;, score=0.885 total time=   0.1s
# [CV 5/5] END criterion=log_loss, max_depth=12, min_samples_leaf=15;, score=0.868 total time=   0.1s
# [CV 1/5] END criterion=gini, max_depth=5, min_samples_leaf=13;, score=0.853 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=5, min_samples_leaf=13;, score=0.828 total time=   0.1s
# [CV 3/5] END criterion=gini, max_depth=5, min_samples_leaf=13;, score=0.864 total time=   0.1s
# [CV 4/5] END criterion=gini, max_depth=5, min_samples_leaf=13;, score=0.878 total time=   0.1s
# [CV 5/5] END criterion=gini, max_depth=5, min_samples_leaf=13;, score=0.855 total time=   0.1s
# [CV 1/5] END criterion=gini, max_depth=15, min_samples_leaf=6;, score=0.884 total time=   0.1s
# [CV 2/5] END criterion=gini, max_depth=15, min_samples_leaf=6;, score=0.843 total time=   0.1s
# [CV 3/5] END criterion=gini, max_depth=15, min_samples_leaf=6;, score=0.881 total time=   0.1s
# [CV 4/5] END criterion=gini, max_depth=15, min_samples_leaf=6;, score=0.885 total time=   0.1s
# [CV 5/5] END criterion=gini, max_depth=15, min_samples_leaf=6;, score=0.880 total time=   0.1s
# [CV 1/5] END criterion=log_loss, max_depth=12, min_samples_leaf=7;, score=0.886 total time=   0.1s
# [CV 2/5] END criterion=log_loss, max_depth=12, min_samples_leaf=7;, score=0.846 total time=   0.1s
# [CV 3/5] END criterion=log_loss, max_depth=12, min_samples_leaf=7;, score=0.882 total time=   0.1s
# [CV 4/5] END criterion=log_loss, max_depth=12, min_samples_leaf=7;, score=0.885 total time=   0.1s
# [CV 5/5] END criterion=log_loss, max_depth=12, min_samples_leaf=7;, score=0.876 total time=   0.1s
# [CV 1/5] END criterion=entropy, max_depth=6, min_samples_leaf=5;, score=0.855 total time=   0.1s
# [CV 2/5] END criterion=entropy, max_depth=6, min_samples_leaf=5;, score=0.830 total time=   0.1s
# [CV 3/5] END criterion=entropy, max_depth=6, min_samples_leaf=5;, score=0.867 total time=   0.1s
# [CV 4/5] END criterion=entropy, max_depth=6, min_samples_leaf=5;, score=0.876 total time=   0.1s
# [CV 5/5] END criterion=entropy, max_depth=6, min_samples_leaf=5;, score=0.857 total time=   0.1s
# [CV 1/5] END criterion=entropy, max_depth=10, min_samples_leaf=11;, score=0.878 total time=   0.1s
# [CV 2/5] END criterion=entropy, max_depth=10, min_samples_leaf=11;, score=0.841 total time=   0.1s
# [CV 3/5] END criterion=entropy, max_depth=10, min_samples_leaf=11;, score=0.876 total time=   0.1s
# [CV 4/5] END criterion=entropy, max_depth=10, min_samples_leaf=11;, score=0.877 total time=   0.1s
# [CV 5/5] END criterion=entropy, max_depth=10, min_samples_leaf=11;, score=0.870 total time=   0.1s
# [CV 1/5] END criterion=gini, max_depth=3, min_samples_leaf=9;, score=0.805 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=3, min_samples_leaf=9;, score=0.821 total time=   0.1s
# [CV 3/5] END criterion=gini, max_depth=3, min_samples_leaf=9;, score=0.835 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=3, min_samples_leaf=9;, score=0.841 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=3, min_samples_leaf=9;, score=0.826 total time=   0.0s
# [CV 1/5] END criterion=log_loss, max_depth=2, min_samples_leaf=5;, score=0.754 total time=   0.0s
# [CV 2/5] END criterion=log_loss, max_depth=2, min_samples_leaf=5;, score=0.754 total time=   0.0s
# [CV 3/5] END criterion=log_loss, max_depth=2, min_samples_leaf=5;, score=0.755 total time=   0.0s
# [CV 4/5] END criterion=log_loss, max_depth=2, min_samples_leaf=5;, score=0.754 total time=   0.0s
# [CV 5/5] END criterion=log_loss, max_depth=2, min_samples_leaf=5;, score=0.754 total time=   0.0s
# [CV 1/5] END criterion=entropy, max_depth=5, min_samples_leaf=11;, score=0.854 total time=   0.1s
# [CV 2/5] END criterion=entropy, max_depth=5, min_samples_leaf=11;, score=0.837 total time=   0.1s
# [CV 3/5] END criterion=entropy, max_depth=5, min_samples_leaf=11;, score=0.859 total time=   0.1s
# [CV 4/5] END criterion=entropy, max_depth=5, min_samples_leaf=11;, score=0.875 total time=   0.1s
# [CV 5/5] END criterion=entropy, max_depth=5, min_samples_leaf=11;, score=0.860 total time=   0.1s
# [CV 1/5] END criterion=gini, max_depth=6, min_samples_leaf=7;, score=0.863 total time=   0.1s
# [CV 2/5] END criterion=gini, max_depth=6, min_samples_leaf=7;, score=0.834 total time=   0.1s
# [CV 3/5] END criterion=gini, max_depth=6, min_samples_leaf=7;, score=0.877 total time=   0.1s
# [CV 4/5] END criterion=gini, max_depth=6, min_samples_leaf=7;, score=0.879 total time=   0.1s
# [CV 5/5] END criterion=gini, max_depth=6, min_samples_leaf=7;, score=0.861 total time=   0.1s
# [CV 1/5] END criterion=log_loss, max_depth=3, min_samples_leaf=10;, score=0.799 total time=   0.0s
# [CV 2/5] END criterion=log_loss, max_depth=3, min_samples_leaf=10;, score=0.801 total time=   0.0s
# [CV 3/5] END criterion=log_loss, max_depth=3, min_samples_leaf=10;, score=0.808 total time=   0.0s
# [CV 4/5] END criterion=log_loss, max_depth=3, min_samples_leaf=10;, score=0.825 total time=   0.0s
# [CV 5/5] END criterion=log_loss, max_depth=3, min_samples_leaf=10;, score=0.817 total time=   0.1s
# [CV 1/5] END criterion=gini, max_depth=9, min_samples_leaf=7;, score=0.881 total time=   0.1s
# [CV 2/5] END criterion=gini, max_depth=9, min_samples_leaf=7;, score=0.838 total time=   0.1s
# [CV 3/5] END criterion=gini, max_depth=9, min_samples_leaf=7;, score=0.877 total time=   0.1s
# [CV 4/5] END criterion=gini, max_depth=9, min_samples_leaf=7;, score=0.883 total time=   0.1s
# [CV 5/5] END criterion=gini, max_depth=9, min_samples_leaf=7;, score=0.873 total time=   0.1s
# [CV 1/5] END criterion=gini, max_depth=13, min_samples_leaf=9;, score=0.881 total time=   0.2s
# [CV 2/5] END criterion=gini, max_depth=13, min_samples_leaf=9;, score=0.837 total time=   0.1s
# [CV 3/5] END criterion=gini, max_depth=13, min_samples_leaf=9;, score=0.880 total time=   0.1s
# [CV 4/5] END criterion=gini, max_depth=13, min_samples_leaf=9;, score=0.879 total time=   0.1s
# [CV 5/5] END criterion=gini, max_depth=13, min_samples_leaf=9;, score=0.874 total time=   0.1s
# [CV 1/5] END criterion=log_loss, max_depth=11, min_samples_leaf=7;, score=0.882 total time=   0.1s
# [CV 2/5] END criterion=log_loss, max_depth=11, min_samples_leaf=7;, score=0.844 total time=   0.1s
# [CV 3/5] END criterion=log_loss, max_depth=11, min_samples_leaf=7;, score=0.876 total time=   0.1s
# [CV 4/5] END criterion=log_loss, max_depth=11, min_samples_leaf=7;, score=0.884 total time=   0.1s
# [CV 5/5] END criterion=log_loss, max_depth=11, min_samples_leaf=7;, score=0.875 total time=   0.1s
# [CV 1/5] END criterion=gini, max_depth=4, min_samples_leaf=13;, score=0.842 total time=   0.1s
# [CV 2/5] END criterion=gini, max_depth=4, min_samples_leaf=13;, score=0.839 total time=   0.1s
# [CV 3/5] END criterion=gini, max_depth=4, min_samples_leaf=13;, score=0.855 total time=   0.1s
# [CV 4/5] END criterion=gini, max_depth=4, min_samples_leaf=13;, score=0.859 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=4, min_samples_leaf=13;, score=0.838 total time=   0.1s
# [CV 1/5] END criterion=log_loss, max_depth=8, min_samples_leaf=5;, score=0.872 total time=   0.1s
# [CV 2/5] END criterion=log_loss, max_depth=8, min_samples_leaf=5;, score=0.841 total time=   0.1s
# [CV 3/5] END criterion=log_loss, max_depth=8, min_samples_leaf=5;, score=0.881 total time=   0.1s
# [CV 4/5] END criterion=log_loss, max_depth=8, min_samples_leaf=5;, score=0.882 total time=   0.1s
# [CV 5/5] END criterion=log_loss, max_depth=8, min_samples_leaf=5;, score=0.868 total time=   0.1s
# [CV 1/5] END criterion=gini, max_depth=10, min_samples_leaf=10;, score=0.873 total time=   0.1s
# [CV 2/5] END criterion=gini, max_depth=10, min_samples_leaf=10;, score=0.839 total time=   0.1s
# [CV 3/5] END criterion=gini, max_depth=10, min_samples_leaf=10;, score=0.881 total time=   0.1s
# [CV 4/5] END criterion=gini, max_depth=10, min_samples_leaf=10;, score=0.882 total time=   0.1s
# [CV 5/5] END criterion=gini, max_depth=10, min_samples_leaf=10;, score=0.872 total time=   0.1s
# [CV 1/5] END criterion=log_loss, max_depth=15, min_samples_leaf=5;, score=0.888 total time=   0.2s
# [CV 2/5] END criterion=log_loss, max_depth=15, min_samples_leaf=5;, score=0.848 total time=   0.1s
# [CV 3/5] END criterion=log_loss, max_depth=15, min_samples_leaf=5;, score=0.880 total time=   0.1s
# [CV 4/5] END criterion=log_loss, max_depth=15, min_samples_leaf=5;, score=0.889 total time=   0.2s
# [CV 5/5] END criterion=log_loss, max_depth=15, min_samples_leaf=5;, score=0.883 total time=   0.1s
# [CV 1/5] END criterion=entropy, max_depth=12, min_samples_leaf=10;, score=0.877 total time=   0.1s
# [CV 2/5] END criterion=entropy, max_depth=12, min_samples_leaf=10;, score=0.838 total time=   0.1s
# [CV 3/5] END criterion=entropy, max_depth=12, min_samples_leaf=10;, score=0.882 total time=   0.1s
# [CV 4/5] END criterion=entropy, max_depth=12, min_samples_leaf=10;, score=0.884 total time=   0.1s
# [CV 5/5] END criterion=entropy, max_depth=12, min_samples_leaf=10;, score=0.872 total time=   0.1s
# [CV 1/5] END criterion=log_loss, max_depth=3, min_samples_leaf=11;, score=0.799 total time=   0.0s
# [CV 2/5] END criterion=log_loss, max_depth=3, min_samples_leaf=11;, score=0.801 total time=   0.0s
# [CV 3/5] END criterion=log_loss, max_depth=3, min_samples_leaf=11;, score=0.808 total time=   0.1s
# [CV 4/5] END criterion=log_loss, max_depth=3, min_samples_leaf=11;, score=0.825 total time=   0.0s
# [CV 5/5] END criterion=log_loss, max_depth=3, min_samples_leaf=11;, score=0.819 total time=   0.1s
# [CV 1/5] END criterion=gini, max_depth=11, min_samples_leaf=10;, score=0.872 total time=   0.1s
# [CV 2/5] END criterion=gini, max_depth=11, min_samples_leaf=10;, score=0.840 total time=   0.1s
# [CV 3/5] END criterion=gini, max_depth=11, min_samples_leaf=10;, score=0.883 total time=   0.1s
# [CV 4/5] END criterion=gini, max_depth=11, min_samples_leaf=10;, score=0.887 total time=   0.1s
# [CV 5/5] END criterion=gini, max_depth=11, min_samples_leaf=10;, score=0.875 total time=   0.1s
# [CV 1/5] END criterion=gini, max_depth=5, min_samples_leaf=8;, score=0.852 total time=   0.1s
# [CV 2/5] END criterion=gini, max_depth=5, min_samples_leaf=8;, score=0.834 total time=   0.1s
# [CV 3/5] END criterion=gini, max_depth=5, min_samples_leaf=8;, score=0.866 total time=   0.1s
# [CV 4/5] END criterion=gini, max_depth=5, min_samples_leaf=8;, score=0.873 total time=   0.1s
# [CV 5/5] END criterion=gini, max_depth=5, min_samples_leaf=8;, score=0.850 total time=   0.1s
# [CV 1/5] END criterion=entropy, max_depth=15, min_samples_leaf=7;, score=0.884 total time=   0.2s
# [CV 2/5] END criterion=entropy, max_depth=15, min_samples_leaf=7;, score=0.847 total time=   0.1s
# [CV 3/5] END criterion=entropy, max_depth=15, min_samples_leaf=7;, score=0.881 total time=   0.1s
# [CV 4/5] END criterion=entropy, max_depth=15, min_samples_leaf=7;, score=0.885 total time=   0.1s
# [CV 5/5] END criterion=entropy, max_depth=15, min_samples_leaf=7;, score=0.881 total time=   0.2s
# [CV 1/5] END criterion=entropy, max_depth=8, min_samples_leaf=15;, score=0.872 total time=   0.1s
# [CV 2/5] END criterion=entropy, max_depth=8, min_samples_leaf=15;, score=0.837 total time=   0.1s
# [CV 3/5] END criterion=entropy, max_depth=8, min_samples_leaf=15;, score=0.874 total time=   0.1s
# [CV 4/5] END criterion=entropy, max_depth=8, min_samples_leaf=15;, score=0.882 total time=   0.1s
# [CV 5/5] END criterion=entropy, max_depth=8, min_samples_leaf=15;, score=0.866 total time=   0.2s
# [CV 1/5] END criterion=gini, max_depth=2, min_samples_leaf=5;, score=0.756 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=2, min_samples_leaf=5;, score=0.767 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=2, min_samples_leaf=5;, score=0.771 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=2, min_samples_leaf=5;, score=0.754 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=2, min_samples_leaf=5;, score=0.754 total time=   0.0s
# [CV 1/5] END criterion=entropy, max_depth=9, min_samples_leaf=5;, score=0.874 total time=   0.1s
# [CV 2/5] END criterion=entropy, max_depth=9, min_samples_leaf=5;, score=0.846 total time=   0.1s
# [CV 3/5] END criterion=entropy, max_depth=9, min_samples_leaf=5;, score=0.871 total time=   0.1s
# [CV 4/5] END criterion=entropy, max_depth=9, min_samples_leaf=5;, score=0.880 total time=   0.1s
# [CV 5/5] END criterion=entropy, max_depth=9, min_samples_leaf=5;, score=0.874 total time=   0.1s
# [CV 1/5] END criterion=log_loss, max_depth=11, min_samples_leaf=9;, score=0.874 total time=   0.1s
# [CV 2/5] END criterion=log_loss, max_depth=11, min_samples_leaf=9;, score=0.839 total time=   0.2s
# [CV 3/5] END criterion=log_loss, max_depth=11, min_samples_leaf=9;, score=0.877 total time=   0.2s
# [CV 4/5] END criterion=log_loss, max_depth=11, min_samples_leaf=9;, score=0.880 total time=   0.2s
# [CV 5/5] END criterion=log_loss, max_depth=11, min_samples_leaf=9;, score=0.871 total time=   0.1s
# [CV 1/5] END criterion=gini, max_depth=2, min_samples_leaf=11;, score=0.756 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=2, min_samples_leaf=11;, score=0.767 total time=   0.1s
# [CV 3/5] END criterion=gini, max_depth=2, min_samples_leaf=11;, score=0.771 total time=   0.1s
# [CV 4/5] END criterion=gini, max_depth=2, min_samples_leaf=11;, score=0.754 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=2, min_samples_leaf=11;, score=0.754 total time=   0.0s
# [CV 1/5] END criterion=log_loss, max_depth=15, min_samples_leaf=10;, score=0.878 total time=   0.1s
# [CV 2/5] END criterion=log_loss, max_depth=15, min_samples_leaf=10;, score=0.837 total time=   0.1s
# [CV 3/5] END criterion=log_loss, max_depth=15, min_samples_leaf=10;, score=0.878 total time=   0.1s
# [CV 4/5] END criterion=log_loss, max_depth=15, min_samples_leaf=10;, score=0.885 total time=   0.2s
# [CV 5/5] END criterion=log_loss, max_depth=15, min_samples_leaf=10;, score=0.874 total time=   0.1s
# [CV 1/5] END criterion=entropy, max_depth=15, min_samples_leaf=9;, score=0.873 total time=   0.1s
# [CV 2/5] END criterion=entropy, max_depth=15, min_samples_leaf=9;, score=0.836 total time=   0.1s
# [CV 3/5] END criterion=entropy, max_depth=15, min_samples_leaf=9;, score=0.879 total time=   0.1s
# [CV 4/5] END criterion=entropy, max_depth=15, min_samples_leaf=9;, score=0.883 total time=   0.1s
# [CV 5/5] END criterion=entropy, max_depth=15, min_samples_leaf=9;, score=0.877 total time=   0.1s
# [CV 1/5] END criterion=log_loss, max_depth=13, min_samples_leaf=5;, score=0.887 total time=   0.1s
# [CV 2/5] END criterion=log_loss, max_depth=13, min_samples_leaf=5;, score=0.848 total time=   0.1s
# [CV 3/5] END criterion=log_loss, max_depth=13, min_samples_leaf=5;, score=0.881 total time=   0.1s
# [CV 4/5] END criterion=log_loss, max_depth=13, min_samples_leaf=5;, score=0.885 total time=   0.2s
# [CV 5/5] END criterion=log_loss, max_depth=13, min_samples_leaf=5;, score=0.881 total time=   0.2s
# [CV 1/5] END criterion=log_loss, max_depth=15, min_samples_leaf=11;, score=0.872 total time=   0.1s
# [CV 2/5] END criterion=log_loss, max_depth=15, min_samples_leaf=11;, score=0.836 total time=   0.1s
# [CV 3/5] END criterion=log_loss, max_depth=15, min_samples_leaf=11;, score=0.877 total time=   0.1s
# [CV 4/5] END criterion=log_loss, max_depth=15, min_samples_leaf=11;, score=0.885 total time=   0.1s
# [CV 5/5] END criterion=log_loss, max_depth=15, min_samples_leaf=11;, score=0.876 total time=   0.1s
# [CV 1/5] END criterion=log_loss, max_depth=4, min_samples_leaf=7;, score=0.835 total time=   0.1s
# [CV 2/5] END criterion=log_loss, max_depth=4, min_samples_leaf=7;, score=0.838 total time=   0.1s
# [CV 3/5] END criterion=log_loss, max_depth=4, min_samples_leaf=7;, score=0.854 total time=   0.1s
# [CV 4/5] END criterion=log_loss, max_depth=4, min_samples_leaf=7;, score=0.859 total time=   0.1s
# [CV 5/5] END criterion=log_loss, max_depth=4, min_samples_leaf=7;, score=0.845 total time=   0.1s
# [CV 1/5] END criterion=gini, max_depth=6, min_samples_leaf=5;, score=0.863 total time=   0.1s
# [CV 2/5] END criterion=gini, max_depth=6, min_samples_leaf=5;, score=0.834 total time=   0.1s
# [CV 3/5] END criterion=gini, max_depth=6, min_samples_leaf=5;, score=0.874 total time=   0.1s
# [CV 4/5] END criterion=gini, max_depth=6, min_samples_leaf=5;, score=0.881 total time=   0.1s
# [CV 5/5] END criterion=gini, max_depth=6, min_samples_leaf=5;, score=0.860 total time=   0.1s
# RandomizedSearchCV(estimator=RandomForestClassifier(random_state=7), n_iter=50,
#                    param_distributions={'criterion': ['gini', 'entropy',
#                                                       'log_loss'],
#                                         'max_depth': range(2, 16),
#                                         'min_samples_leaf': range(5, 16)},
#                    verbose=4)

# %%
# 모델 파라미터
print(f'[searchCV.best_score_] {searchCV.best_score_}')
print(f'[searchCV.best_params_] {searchCV.best_params_}')
print(f'[searchCV.best_estimator_] {searchCV.best_estimator_}')

cv_resultDF = pd.DataFrame(searchCV.cv_results_)
cv_resultDF
# Out:
# [searchCV.best_score_] 0.8751245650403494
# [searchCV.best_params_] {'min_samples_leaf': 6, 'max_depth': 13}
# [searchCV.best_estimator_] RandomForestClassifier(max_depth=13, min_samples_leaf=6, random_state=7)
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.202145      0.016666         0.010868        0.004149
# 1        0.185734      0.003164         0.013209        0.003077
# 2        0.141447      0.006508         0.006116        0.006710
# 3        0.170837      0.011305         0.006177        0.007045
# 4        0.167638      0.005728         0.008737        0.004454
# 5        0.122388      0.005898         0.004584        0.005304
# 6        0.183593      0.001874         0.012007        0.002810
# 7        0.165309      0.006624         0.012209        0.006522
# 8        0.129795      0.006393         0.007298        0.004948
# 9        0.133715      0.000721         0.006219        0.007649
# 10       0.188034      0.010623         0.009731        0.007957
# 11       0.181297      0.005850         0.011991        0.004311
# 12       0.152555      0.002528         0.004984        0.006288
# 13       0.191545      0.007719         0.010695        0.005587
# 14       0.182158      0.005795         0.008811        0.005698
# 15       0.187754      0.003498         0.009384        0.000574
# 16       0.164759      0.005337         0.008062        0.004684
# 17       0.156118      0.004943         0.005889        0.003535
# 18       0.201515      0.007208         0.011119        0.006780
# 19       0.132809      0.004230         0.006160        0.001278
# 20       0.186894      0.008045         0.005325        0.004361
# 21       0.137163      0.008089         0.005697        0.003925
# 22       0.191429      0.007500         0.008672        0.005508
# 23       0.165145      0.008013         0.008154        0.005329
# 24       0.152317      0.011322         0.009411        0.002026
# 25       0.184579      0.017086         0.002739        0.003930
# 26       0.182065      0.012411         0.008337        0.006789
# 27       0.137945      0.008044         0.006250        0.007655
# 28       0.190266      0.005609         0.012491        0.006721
# 29       0.183290      0.003930         0.010523        0.007176
# 30       0.187668      0.010911         0.011476        0.005979
# 31       0.195010      0.004851         0.011628        0.004712
# 32       0.190033      0.005933         0.017107        0.003534
# 33       0.161837      0.011813         0.008270        0.007062
# 34       0.199798      0.000917         0.010062        0.006062
# 35       0.185315      0.009313         0.006850        0.006054
# 36       0.127350      0.005813         0.002764        0.005528
# 37       0.125880      0.010472         0.005041        0.005762
# 38       0.159964      0.008514         0.005669        0.005783
# 39       0.197096      0.005297         0.011355        0.008778
# 40       0.131863      0.007408         0.003616        0.005252
# 41       0.195844      0.005711         0.006565        0.005161
# 42       0.179661      0.014211         0.011372        0.008125
# 43       0.182827      0.010726         0.007374        0.006430
# 44       0.189839      0.004568         0.009738        0.005022
# 45       0.238973      0.056117         0.010726        0.007254
# 46       0.164236      0.003400         0.009258        0.005956
# 47       0.195231      0.006576         0.012018        0.006948
# 48       0.190578      0.006205         0.012477        0.006714
# 49       0.198745      0.005783         0.009704        0.005049
#
#     param_min_samples_leaf  param_max_depth  \
# 0                        6               13
# 1                        9               14
# 2                       14                4
# 3                       10                6
# 4                       14                7
# 5                        9                2
# 6                        9               13
# 7                        5                7
# 8                        9                3
# 9                       10                3
# 10                       9               15
# 11                      12               14
# 12                       7                5
# 13                       8               15
# 14                      14               14
# 15                      11               15
# 16                      11                6
# 17                      11                5
# 18                       5               12
# 19                      15                3
# 20                      14               10
# 21                      13                3
# 22                      11               14
# 23                      12                6
# 24                      12                4
# 25                       9                6
# 26                      12                7
# 27                       5                3
# 28                       9               10
# 29                      11                9
# 30                       8                9
# 31                       5                9
# 32                       7               10
# 33                      15                6
# 34                       6               11
# 35                      10                8
# 36                      10                2
# 37                      15                2
# 38                       8                5
# 39                       5               11
# 40                      11                2
# 41                      11                8
# 42                       8                7
# 43                       7                7
# 44                      15               14
# 45                       6               15
# 46                      14                5
# 47                      10               11
# 48                      14               12
# 49                      12               15
#
#                                        params  split0_test_score  \
# 0    {'min_samples_leaf': 6, 'max_depth': 13}           0.882692
# 1    {'min_samples_leaf': 9, 'max_depth': 14}           0.878846
# 2    {'min_samples_leaf': 14, 'max_depth': 4}           0.841346
# 3    {'min_samples_leaf': 10, 'max_depth': 6}           0.865385
# 4    {'min_samples_leaf': 14, 'max_depth': 7}           0.868269
# 5     {'min_samples_leaf': 9, 'max_depth': 2}           0.755769
# 6    {'min_samples_leaf': 9, 'max_depth': 13}           0.880769
# 7     {'min_samples_leaf': 5, 'max_depth': 7}           0.867308
# 8     {'min_samples_leaf': 9, 'max_depth': 3}           0.804808
# 9    {'min_samples_leaf': 10, 'max_depth': 3}           0.804808
# 10   {'min_samples_leaf': 9, 'max_depth': 15}           0.878846
# 11  {'min_samples_leaf': 12, 'max_depth': 14}           0.875000
# 12    {'min_samples_leaf': 7, 'max_depth': 5}           0.853846
# 13   {'min_samples_leaf': 8, 'max_depth': 15}           0.878846
# 14  {'min_samples_leaf': 14, 'max_depth': 14}           0.872115
# 15  {'min_samples_leaf': 11, 'max_depth': 15}           0.876923
# 16   {'min_samples_leaf': 11, 'max_depth': 6}           0.863462
# 17   {'min_samples_leaf': 11, 'max_depth': 5}           0.853846
# 18   {'min_samples_leaf': 5, 'max_depth': 12}           0.879808
# 19   {'min_samples_leaf': 15, 'max_depth': 3}           0.801923
# 20  {'min_samples_leaf': 14, 'max_depth': 10}           0.875000
# 21   {'min_samples_leaf': 13, 'max_depth': 3}           0.803846
# 22  {'min_samples_leaf': 11, 'max_depth': 14}           0.875962
# 23   {'min_samples_leaf': 12, 'max_depth': 6}           0.862500
# 24   {'min_samples_leaf': 12, 'max_depth': 4}           0.841346
# 25    {'min_samples_leaf': 9, 'max_depth': 6}           0.864423
# 26   {'min_samples_leaf': 12, 'max_depth': 7}           0.869231
# 27    {'min_samples_leaf': 5, 'max_depth': 3}           0.804808
# 28   {'min_samples_leaf': 9, 'max_depth': 10}           0.876923
# 29   {'min_samples_leaf': 11, 'max_depth': 9}           0.870192
# 30    {'min_samples_leaf': 8, 'max_depth': 9}           0.876923
# 31    {'min_samples_leaf': 5, 'max_depth': 9}           0.875000
# 32   {'min_samples_leaf': 7, 'max_depth': 10}           0.876923
# 33   {'min_samples_leaf': 15, 'max_depth': 6}           0.860577
# 34   {'min_samples_leaf': 6, 'max_depth': 11}           0.878846
# 35   {'min_samples_leaf': 10, 'max_depth': 8}           0.873077
# 36   {'min_samples_leaf': 10, 'max_depth': 2}           0.755769
# 37   {'min_samples_leaf': 15, 'max_depth': 2}           0.755769
# 38    {'min_samples_leaf': 8, 'max_depth': 5}           0.851923
# 39   {'min_samples_leaf': 5, 'max_depth': 11}           0.883654
# 40   {'min_samples_leaf': 11, 'max_depth': 2}           0.755769
# 41   {'min_samples_leaf': 11, 'max_depth': 8}           0.871154
# 42    {'min_samples_leaf': 8, 'max_depth': 7}           0.871154
# 43    {'min_samples_leaf': 7, 'max_depth': 7}           0.868269
# 44  {'min_samples_leaf': 15, 'max_depth': 14}           0.873077
# 45   {'min_samples_leaf': 6, 'max_depth': 15}           0.883654
# 46   {'min_samples_leaf': 14, 'max_depth': 5}           0.852885
# 47  {'min_samples_leaf': 10, 'max_depth': 11}           0.872115
# 48  {'min_samples_leaf': 14, 'max_depth': 12}           0.870192
# 49  {'min_samples_leaf': 12, 'max_depth': 15}           0.872115
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.845192           0.881617           0.883542
# 1            0.838462           0.879692           0.885467
# 2            0.840385           0.857555           0.859480
# 3            0.836538           0.869105           0.879692
# 4            0.838462           0.871030           0.878730
# 5            0.767308           0.770934           0.753609
# 6            0.836538           0.879692           0.878730
# 7            0.834615           0.872955           0.875842
# 8            0.821154           0.835419           0.841193
# 9            0.821154           0.837344           0.842156
# 10           0.840385           0.881617           0.883542
# 11           0.832692           0.879692           0.882579
# 12           0.835577           0.867180           0.873917
# 13           0.842308           0.876805           0.878730
# 14           0.832692           0.873917           0.879692
# 15           0.837500           0.878730           0.884504
# 16           0.834615           0.871030           0.878730
# 17           0.826923           0.863330           0.872955
# 18           0.850000           0.884504           0.882579
# 19           0.819231           0.835419           0.841193
# 20           0.831731           0.878730           0.880654
# 21           0.819231           0.837344           0.845043
# 22           0.838462           0.877767           0.883542
# 23           0.832692           0.872955           0.876805
# 24           0.841346           0.855630           0.859480
# 25           0.830769           0.872955           0.880654
# 26           0.833654           0.877767           0.878730
