# %% [markdown]
# 데이터 탐색적 분석 => 지도/비지도/강화
# 학습 알고리즘 => 선형모델
# - 피쳐와 타겟의 관계 선형관계
# - 정규분포 기반
# - 선형식 : y = ax + b => wx + b => w0+w1x
#             y = w0 + w1x + w2x + .... + wnx
# - Coeffiecent 또는 Weight
#     : 학습을 통해서 다양한 피쳐들의 영향 정도를 정확하게 반영하기 위해서 사용됨.
# - 일반화된 모델을 만들기 위해 Feature의 수는 적은게 좋음
# - 매개변수들의 가중치를 조절해주기 위해 릿지(영향력이 적은 피쳐를 가중치 0으로 만들면서 단순하게 만듬. => 과대 적합으로 가는 것을 막음.), 라쏘, 엘라스틴 씀
# - |w|1 => 절댓값

# %% [markdown]
# * 전처리 : 모든 것을 수치화 => 범주형 : 인코딩 {소분류 >> 대분류}

# %% [markdown]
# 파라미터
# * 모델 파라미터
# : fit() 학습 진행 후 설정되는 변수
# : 모델 파라미터명_
#
# * 하이퍼 파라미터
# : 모델 인스턴스 생성시 매개변수
# : 모델 인스턴스 생성시 개발자가 값을 설정
# : 모델 성능에 영향 미침 !!
# : 예) 규재강도 alpha(값이 커질수록 규제 강도가 강해짐), K 개수, 학습 횟수 max_iter
#       규제강도 C(값이 커질수록 규제 강도 약해짐)
#
# * 튜닝
# : 모델의 성능을 높이는 작업
# 즉, 모델의 하이퍼파라미터의 값을 조절해서 성능 올리기.

# %% [markdown]
# 좋은 모델
# - 일반화가 잘된 모델
# - 모델 복잡도 ==> 간소한 모델(피쳐 수가 간소한 것)
